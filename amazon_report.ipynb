# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
info = pd.read_csv('reports.csv')
info = info.fillna(0)
#info['Item Total']
info['Item Total'] = info['Item Total'].str.replace('$','', regex = False).astype(float)

# %%
info['Item Total'].sum()
info['Item Total'].mean()
info['Item Total'].max()
info['Item Total'].min()
print(f'Total spending: ${total}')
print(f'Average order cost: ${avg:.2f}')
print(f'Highest purchase cost: ${maxi}')
print(f'Lowest purchase cost: ${mini}')
# Out:
# Total spending: $187.78
# Average order cost: $12.52
# Highest purchase cost: $42.2
# Lowest purchase cost: $4.3

# %%
indv_order = info.groupby('Order Date').sum()['Item Total']
indv_order.plot.bar(figsize = (25,15), fontsize = 15, ylabel = 'Dollars')
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Dollars'>
